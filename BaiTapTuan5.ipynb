# %% [markdown]
# # Bài tập tuần 5 – Hàm

# %% [markdown]
# ### W5A1
# Viết hàm truyền vào hai số nguyên a, b. Trả về số lớn hơn trong hai số. def Max_Of_Two(a, b) -> int:

# %%
def max(a,b):
    if a>b:
        return a
    else:
        return b

# %% [markdown]
# ### W5A2
# Viết hàm hoán đổi hai số nguyên. def swap(a, b) -> Tuple[int, int]:

# %%
def swap(a,b):
    c=a
    a=b
    b=c
    return(a,b)

# %% [markdown]
# ### W5A3
# Viết hàm kiểm tra một số có phải là số nguyên tố hay không?

# %%
def nguyento(n):
    if n<2:
        return False
    for i in range(2,n):
        if n%i==0:
            return False
        return True

# %% [markdown]
# ### W5A4 W5A5
# Viết hàm kiểm tra một số có phải số hoàn hảo hay không, xử lý trên dữ liệu kiểu số nguyên.
#
# Viết hàm đưa vào một list số nguyên và một số nguyên dương k. Hãy tìm và trả về vị trí của phần tử đầu tiên có giá trị k trong list số nguyên, nếu không có thì trả về -1

# %%
def sohoanhao(n):
    uoc=0
    for i in range(1,n):
        if n%i==0:
            uoc+=i
    if uoc==n:
        return True
    else:
        return False
print(sohoanhao(28))
# Out:
# True

# %% [markdown]
# ### W5A6
# Viết hàm tính giai thừa. Nhập vào số nguyên n, trả về giai thừa của n (n!)

# %%
def giaithua(n):
    gt=1
    for i in range(1,n+1):
        gt*=i
    return gt

# %% [markdown]
# ### W5A7
# Viết hàm giả lập một máy tính bỏ túi. Hàm thực hiện tính toán kết quả của phép toán giữa số num1 và num2 với toán tử operator.
# Biết các toán tử đơn giản thực hiện phép toán lần lượt là:
# Phép trừ (-)
# Phép cộng (+)
# Phép chia (/)
# Phép nhân (*)
# Kết quả làm tròn đến chữ số thập phân thứ hai.
# Đầu vào: Hai số thực và phép toán cần thực hiện (trong số các phép toán +, -, *, /).
# Đầu ra: Kết quả phép toán.

# %% [markdown]
# ### W5A8 W5A9
# Khoảng cách Hamming giữa hai số nguyên là số lượng vị trí khác nhau giữa hai dây bits tương ứng của chúng... Cho hai số nguyên x và y, hãy viết hàm trả về khoảng cách Hamming giữa hai số này.
#
# Viết hàm trả về tổng các chữ số của số nguyên dương n

# %% [markdown]
# ### W5A10
# Hai từ được gọi là đẳng cấu nếu các kí tự trong một từ có thể được ánh xạ để được từ còn lại... Viết hàm trả về true nếu hai từ a và b là đẳng cấu, ngược lại false. Bạn có thể giả sử hai từ đầu vào có cùng độ dài.

# %% [markdown]
# ### W5A11
# Viết hàm is_product_divisible_by_10(a, b) trả về True nếu tích a b chia hết cho 10, ngược lại False.

# %%
def is_product_divisible_by_10(a,b):
    if (a*b)%10==0:
        return True
    return False

# %% [markdown]
# ### W5A12
# Viết hàm divide_with_remainder(dividend, divisor) trả về bộ (q, r) sao cho dividend = divisor*q + r và 0 <= |r| < |divisor|.

# %%
def divide_with_remainder(dividend,divisor):

# %% [markdown]
# ### W5A13
# Viết hàm max of two(a, b) trả về số lớn hơn trong hai số.

# %%
def max_of_two(a,b):
    if a>b:
        return a
    return b

# %% [markdown]
# ### W5A14
# Viết hàm compute(a, b, op) thực hiện phép tính a (+ - * /) b tùy theo ký tự op.

# %% [markdown]
# ### W5A15
# Viết hàm is_right_triangle(a, b, c) trả về True nếu ba số có thể là ba cạnh của tam giác vuông.

# %%
def is_right_triangle(a,b,c):
    if a+b>c and a+c>b and b+c>a:
        return True
    return False
