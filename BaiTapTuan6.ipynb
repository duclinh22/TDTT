# %% [markdown]
# ### W6A1
# Nhập vào một dòng gồm các số nguyên. Hãy loại bỏ phần tử trùng nhưng giữ nguyên thứ tự xuất hiện đầu tiên, rồi in ra list kết quả. Yêu cầu in ra đúng dạng list Python, ví dụ [1, 2, 3]

# %%
n=list(map(int,input().split()))
seen=set()
lst=[]
for i in n:
    if i not in lst:
        lst.append(i)
print(lst)
# Out:
# [5, 4, 3, 6]

# %% [markdown]
# ### W6A2
# Nhập một dòng số nguyên. In ra list tổng tích lũy (phần tử i là tổng từ đầu tới vị trí i), giữ nguyên thứ tự

# %%
n=list(map(int,input().split()))
lst=[]
tong=0
for i in n:
    tong+=int(i)
    lst.append(tong)
print(lst)
# Out:
# [1, 3, 6, 10, 15, 21, 28, 36, 45]

# %% [markdown]
# ### W6A3
# Nhập một tuple số nguyên (một dòng) và số nguyên k (dòng kê). In ra tuple sau khi xoay trái k vị trí. (Giữ nguyên thứ tự tương đối sau xoay; không sắp xếp.)

# %%
lst=list(map(int,input().split()))
k=int(input())
n=len(lst)
lst_kq=[]
if k>n:
    k=k%n
for i in range(k,n):
    lst_kq.append(lst[i])
for i in range(0,k):
    lst_kq.append(lst[i])
print(lst_kq)
# Out:
# [3, 4, 5, 6, 1, 2]

# %% [markdown]
# ### W6A4
# Nhập một dòng gồm các cặp key:value cách nhau bởi dấu cách. Tạo dictionary ánh xạ mỗi key -> list các value theo thứ tự xuất hiện. Nếu key lặp lại, thêm vào list của key đó

# %%
data=input().split()
ketqua={}
for i in data:
    key,value=i.split(':')
    if key not in ketqua:
        ketqua[key]=[value]
    else:
        ketqua[key].append(value)
print(ketqua)

# %% [markdown]
# ### W6A5
# Nhập một list số nguyên, In ra dictionary {'positives': ...., 'negatives': ..., 'zeros': ...} (đếm số >0, <0, =0)

# %%
songuyen=map(int,input().split())
lst={'positives':0,'negatives':0,'zeros':0}
for i in songuyen:
    if i>0:
        lst['positives']+=1
    elif i<0:
        lst['negatives']+=1
    else:
        lst['zeros']+=1
print(lst)
# Out:
# {'positives': 0, 'negatives': 3, 'zeros': 0}

# %% [markdown]
# ### W6A6
# Viết chương trình nhập vào một danh sách các số nguyên, sau đó in ra tổng các số trong list đó.

# %%
n=map(int,input().split())
tong=0
for i in n:
    tong+=i
print(tong)
# Out:
# -3

# %% [markdown]
# ### W6A7
# Viết chương trình nhập vào một tuple, in ra phần tử đầu, phân tử cuối, và tuple đảo ngược

# %%
dulieu=tuple(input().split()) #tuple là kiểu dữ liệu nằm trong dấu (),không thể thay đổi
print(dulieu[0],dulieu[-1],dulieu[::-1])
# Out:
# VNU Mechatronics ('Mechatronics', '2026', 'VNU')

# %% [markdown]
# ### W6A8
# Viết chương trình nhập vào một list các chuỗi, sau đó đếm số lần xuất hiện của từng chuỗi và lưu vào dictionary.

# %%
data=input().split()
dictionary={}
for i in data:
    if i not in dictionary:
        dictionary[i]=1
    else:
        dictionary[i]+=1
print(dictionary)
# Out:
# {'Python': 3, 'Java': 1, 'C++': 1}

# %% [markdown]
# ### W6A9
# Viết chương trình nhập vào hai dictionary. Sau đó gộp lại thành một dictionary mới trong đó nếu một key xuất hiện trong cả hai dict, giá trị sẽ được cộng lại, nếu chỉ có trong một dict thì giữ nguyên. In ra dictionary mới theo thứ tự từ điển tăng dần của key.

# %%
data1=input().split()
data2=input().split()
dic1={}
for i in data1:
    key,value=i.split(':')
    value=int(value)
    if key not in dic1:
        dic1[key]=value
    else:
        dic1[key]+=value
for key in data2:
    key,value=i.split(':')
    value=int(value)
    if i not in dic1:
        dic1[key]=value
    else:
        dic1[key]+=value
print(dic1)
# Out:
# {'a': 10, 'b': 5, 'c': 30}

# %% [markdown]
# ### W6A10
# Viết chương trình nhập vào một danh sách các số nguyên, và số nguyên dương k. In ra list gồm các cặp số khác nhau có tổng bằng k. Mỗi cặp là một tuple, hai số trong tuple có thể giống nhau, thứ tự xuất hiện trong danh sách của số thứ nhất nhỏ hơn thứ tự của số thứ hai. Các tuple trong list được sắp xếp theo thứ tự tăng dần của phần tử đầu tiên trong tuple.

# %%
lst=list(map(int,input().split()))
k=int(input())
lst1=[]
for i in range(len(lst)):
    for j in range(i+1,len(lst)):
        if lst[i]+lst[j]==k:
            tup=(lst[i],lst[j])
            if tup not in lst1:
                lst1.append(tup)
lst1.sort()
print(lst1)
# Out:
# [(1, 5), (4, 2)]

# %% [markdown]
# ### W6A11
# [Tách số chẵn và lẻ từ tuple] Nhập vào một tuple chứa các số nguyên. Hãy tạo ra hai tuple mới: một chứa tất cả các số chẵn và một chứa tất cả các số lẻ từ tuple ban đầu, giữ nguyên thứ tự tương đối. In ra hai tuple này trên hai dòng riêng biệt.

# %%
data1=map(int,input().split())
lst1=[]
lst2=[]
for i in data1:
    if i%2==0:
        lst1.append(i)
    else:
        lst2.append(i)
tup1=tuple(lst1)
tup2=tuple(lst2)
print(tup1)
print(tup2)
# Out:
# (2, 4, 6)
# (1, 3, 5)

# %% [markdown]
# ### W6A12
# [Tìm phần tử xuất hiện nhiều nhất] Nhập vào một list các số nguyên. Hãy tìm số xuất hiện nhiều lần nhất trong list. Nếu có nhiều số cùng có số lần xuất hiện nhiều nhất, hãy in ra số nhỏ nhất trong số đó.

# %%
data=list(map(int,input().split()))
data.sort()
max=0
giatri=0
for i in data:
    if data.count(i)>max:
        max=data.count(i)
        giatri=i
print(giatri)
# Out:
# 2

# %% [markdown]
# ### W6A13
# [Đảo ngược key và value của dictionary] Nhập vào một dictionary có value là duy nhất (không trùng nhau). Hãy tạo một dictionary mới bằng cách đảo ngược key và value của dictionary ban đầu. In ra dictionary mới.

# %%
data=input().split() #Nhap du lieu
#cat key value tu du lieu
data1={}
for i in data:
    value,key=i.split(':')
    data1[key]=value
print(data1)
# Out:
# {'Vietnam': 'VN', 'English': 'EN', 'Japan': 'JP'}

# %% [markdown]
# ### W6A14
# [Giao của hai danh sách] Nhập vào hai dòng, mỗi dòng là một danh sách các số nguyên. Hãy tìm các phần tử chung (giao) của hai danh sách này và in ra một list mới chứa các phần tử chung đó, không trùng lặp.

# %%
lst1=set(map(int,input().split()))
lst2=set(map(int,input().split()))
lst=[]
for i in lst1:
    if i in lst2:
        lst.append(i)
print(lst)
# Out:
# [3, 4]

# %% [markdown]
# ### W6A15
# [Lọc dictionary theo giá trị] Nhập vào một dictionary có key là chuỗi và value là số nguyên, và một số nguyên k ở dòng tiếp theo. Hãy tạo một dictionary mới chỉ chứa các cặp key-value từ dictionary ban đầu mà có value lớn hơn k. In ra dictionary mới.

# %%
data=input().split()
k=int(input())
dic1={}
for i in data:
    key,value=i.split(':')
    if int(value)>k:
        dic1[key]=int(value)
print(dic1)
# Out:
# {'p': 15}
